# %%
import os
from typing import List

from typing_extensions import TypedDict, Annotated

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek
from langchain_openai import ChatOpenAI

load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    extra_body={
        "thinking": {"type": "disabled"}
    }
)

# %%
class Change(TypedDict):
    """成就"""
    year : Annotated[str , "年份"]
    title : Annotated[str , "事件"]

class Person(TypedDict):
    """人物信息"""
    name : Annotated[str , "姓名"]
    sex : Annotated[str , "性别"]
    age : Annotated[int , "年龄"]
    change : Annotated[List[Change] , "成就"]

model = llm_deepseek.with_structured_output(Person)
res = model.invoke("介绍习近平")
print(res)
# Out:
# {'name': '习近平', 'sex': '男', 'age': 71, 'change': [{'year': '2012年', 'title': '当选中国共产党中央委员会总书记'}, {'year': '2013年', 'title': '当选中华人民共和国主席'}, {'year': '2017年', 'title': '再次当选中国共产党中央委员会总书记'}, {'year': '2018年', 'title': '再次当选中华人民共和国主席'}, {'year': '2022年', 'title': '第三次当选中国共产党中央委员会总书记'}, {'year': '2023年', 'title': '第三次当选中华人民共和国主席'}]}
