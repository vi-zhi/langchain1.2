# %% [raw]
# # ChatPromptTemple

# %%
from langchain_core.prompts import ChatPromptTemplate, SystemMessagePromptTemplate

chat_prompt_template=ChatPromptTemplate.from_messages([
    ("system","你是一个友好的AI助手,你的名字叫{name}"),
    ("human","你好,最近怎么样?"),
    ("ai","我很好,谢谢"),
    ("human","{user_input}")
])

chat=chat_prompt_template.invoke({"name":"胡海涛","user_input":"1+1=?"})
print(chat)
# Out:
# messages=[SystemMessage(content='你是一个友好的AI助手,你的名字叫胡海涛', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好,最近怎么样?', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好,谢谢', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='1+1=?', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template=ChatPromptTemplate.from_messages([
    ("system","你是一个友好的AI助手,你的名字叫{name}"),
    ("human","你好,最近怎么样?"),
    ("ai","我很好,谢谢"),
    ("human","{user_input}")
])

chat=chat_prompt_template.format(name="hht" , user_input="1=2")
print(chat)
# Out:
# System: 你是一个友好的AI助手,你的名字叫hht
# Human: 你好,最近怎么样?
# AI: 我很好,谢谢
# Human: 1=2

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template=ChatPromptTemplate.from_messages([
    ("system","你是一个友好的AI助手,你的名字叫{name}"),
    ("human","你好,最近怎么样?"),
    ("ai","我很好,谢谢"),
    ("human","{user_input}")
])

chat=chat_prompt_template.format_messages(name="hht" , user_input="1=2")
print(chat)
print(type(chat))
# Out:
# [SystemMessage(content='你是一个友好的AI助手,你的名字叫hht', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好,最近怎么样?', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好,谢谢', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='1=2', additional_kwargs={}, response_metadata={})]
# <class 'list'>

# %%
import os

from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_core.messages import HumanMessage

load_dotenv(override=True)

model = init_chat_model(
    model="qwen3.6-plus",
    model_provider="openai",
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url=os.getenv("DASHSCOPE_BASE_URL")
)

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template=ChatPromptTemplate.from_messages([
    ("system","你是一个友好的AI助手,你的名字叫{name}"),
    ("human","你好,最近怎么样?"),
    ("ai","我很好,谢谢"),
    ("human","{user_input}")
])

chat=chat_prompt_template.invoke({"name":"胡海涛","user_input":"1+1=?"})

res=model.invoke(chat)
print(res)
# Out:
# content='1+1=2 哦！如果还有其他问题或者想聊点什么，随时告诉我呀～ 😊' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 253, 'prompt_tokens': 47, 'total_tokens': 300, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 226, 'rejected_prediction_tokens': None, 'text_tokens': 253}, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3.6-plus', 'system_fingerprint': None, 'id': 'chatcmpl-bb5ccbdb-e7e0-9e4d-9fce-356714245304', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f9d49-9ff1-7322-bb6d-b5e69099e3e6-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 47, 'output_tokens': 253, 'total_tokens': 300, 'input_token_details': {}, 'output_token_details': {'reasoning': 226}}

# %%
chat=ChatPromptTemplate.from_messages([
    "你好,我是{name}",
])
print(chat.invoke({"name":"hht"}))
# Out:
# messages=[HumanMessage(content='你好,我是hht', additional_kwargs={}, response_metadata={})]

# %%
chat=ChatPromptTemplate.from_messages([
    ("system","你是ai助手"),
    ("human","你好，{name}"),
])
print(chat.invoke({"name":"hht"}))
# Out:
# messages=[SystemMessage(content='你是ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，hht', additional_kwargs={}, response_metadata={})]

# %%
chat=ChatPromptTemplate.from_messages([
    {"role":"system","content":"你是ai助手"},
    {"role":"human","content":"你好，{name}"},
])
print(chat.invoke({"name":"hht"}))
# Out:
# messages=[SystemMessage(content='你是ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，hht', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import SystemMessagePromptTemplate,HumanMessagePromptTemplate

sys=SystemMessagePromptTemplate.from_template("你是ai助手")
hum=HumanMessagePromptTemplate.from_template("你好，{name}")

chat=ChatPromptTemplate.from_messages([
    sys,
    hum
])
print(chat.invoke({"name":"hht"}))
# Out:
# messages=[SystemMessage(content='你是ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，hht', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import SystemMessagePromptTemplate,HumanMessagePromptTemplate

sys=ChatPromptTemplate.from_messages([("system","你是ai助手")])
hum=ChatPromptTemplate.from_messages([("human","你好，{name}")])

chat=ChatPromptTemplate.from_messages([
    sys,
    hum
])
print(chat.invoke({"name":"hht"}))
# Out:
# messages=[SystemMessage(content='你是ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，hht', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import SystemMessagePromptTemplate,HumanMessagePromptTemplate

sys=ChatPromptTemplate.from_template("你是ai助手")
hum=ChatPromptTemplate.from_template("你好，{name}")

chat=ChatPromptTemplate.from_messages([
    sys,
    hum
])
print(chat.invoke({"name":"hht"}))
# Out:
# messages=[HumanMessage(content='你是ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，hht', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate

#?原始模板
template = ChatPromptTemplate.from_messages ([
    ("system","你是{role},目标用户是{audience}"),
    ("user", "{task}")
])

fin_tem=template.partial(role="导游", audience="游客")

result1=fin_tem.invoke({"task":"介绍一下北京的故宫"})
result2=fin_tem.invoke({"task":"介绍一下北京的顾和园"})

print(result1)
print(result2)
# Out:
# messages=[SystemMessage(content='你是导游,目标用户是游客', additional_kwargs={}, response_metadata={}), HumanMessage(content='介绍一下北京的故宫', additional_kwargs={}, response_metadata={})]
# messages=[SystemMessage(content='你是导游,目标用户是游客', additional_kwargs={}, response_metadata={}), HumanMessage(content='介绍一下北京的顾和园', additional_kwargs={}, response_metadata={})]

# %%
template=ChatPromptTemplate.from_messages([
    ("system","我是一个ai助手"),
    ("placeholder","{conversation}")
])

res = template.invoke({
    "conversation" :[
        ("human","你好,请问明天的天气如何?"),
        ("ai","明天天气晴朗"),
        ("human","后天的天气怎么样?")
    ]
})

print(res)
# Out:
# messages=[SystemMessage(content='我是一个ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好,请问明天的天气如何?', additional_kwargs={}, response_metadata={}), AIMessage(content='明天天气晴朗', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='后天的天气怎么样?', additional_kwargs={}, response_metadata={})]
