# %% [markdown]
# # 输入的格式化

# %%
import os

from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_core.messages import HumanMessage

load_dotenv(override=True)

model = init_chat_model(
    model="qwen3.6-plus",
    model_provider="openai",
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url=os.getenv("DASHSCOPE_BASE_URL")
)

# %%
import base64

def encode_image(img_path, img_type='jpeg'):
    """将一张本地图片转换成 Base64 编码的 Data URI 字符串，方便在文本中嵌入图片数据"""
    with open(img_path, "rb") as img_file:
        return f"data:image/{img_type};base64,{base64.b64encode(img_file.read()).decode('utf-8')}"

base64_image = encode_image("img.png")

response=model.invoke(
    [
            HumanMessage(
             content_blocks=[
                {'type':'text' , 'text':'这个图片是啥'},
                {
                    'type':'image_url',
                    'image_url':base64_image,
                    'mime_type':'image/png',
                }
            ]
        )
    ]
)

print(response.content)
# Out:
# 这张图片展示的是一瓶**粉底液**（化妆品）。
#
# 具体来说，从它的外观特征来看：
# 1.  **瓶身**：透明的方形玻璃瓶。
# 2.  **液体**：里面装着米色/浅褐色的液体，这是典型的粉底液颜色。
# 3.  **瓶盖**：金色的方形盖子，带有按压泵头。
#
# **推测品牌：**
# 虽然图片比较模糊看不清具体的文字，但这个经典的“方瓶+金盖”设计非常像 **雅诗兰黛（Estée Lauder）的 Double Wear 持妆粉底液**（俗称“DW粉底液”）。这是市面上非常热门的一款粉底产品。
#
# **其他细节：**
# 图片右侧有一个黑色的**鼠标箭头**，说明这很可能是一张电脑屏幕的截图，你可能是在浏览电商网站（如淘宝、京东）或者美妆官网时截下来的。

# %% [markdown]
# # 输出格式化

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv()
load_dotenv(override=True)

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    extra_body={"thinking": {"type": "enabled"}},
)

response = model.invoke("你好，一句话回答")
print('=' * 20, '-> response <-', '=' * 20)
print(response)
print('=' * 20, '-> response.content <-', '=' * 20)
print(response.content)
print('=' * 20, '-> response.content_blocks <-', '=' * 20)
print(response.content_blocks)
# Out:
# ==================== -> response <- ====================
# content='你好！有什么需要帮忙的吗？' additional_kwargs={'refusal': None, 'reasoning_content': '用户打招呼，需要简洁回应。作为AI助手，用友好态度表明身份和功能即可。考虑用问候开头，提供清晰帮助范围，保持回复精炼符合用户要求。'} response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 8, 'total_tokens': 54, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 38, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '78979945-e165-48eb-9a4c-f6775fba3767', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f9d0a-99ed-73e2-89d0-a6abfc825b87-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 46, 'total_tokens': 54, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 38}}
# ==================== -> response.content <- ====================
# 你好！有什么需要帮忙的吗？
# ==================== -> response.content_blocks <- ====================
# [{'type': 'reasoning', 'reasoning': '用户打招呼，需要简洁回应。作为AI助手，用友好态度表明身份和功能即可。考虑用问候开头，提供清晰帮助范围，保持回复精炼符合用户要求。'}, {'type': 'text', 'text': '你好！有什么需要帮忙的吗？'}]
